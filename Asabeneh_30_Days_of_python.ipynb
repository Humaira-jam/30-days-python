# %% [markdown]
# <a href="https://colab.research.google.com/github/Humaira-jam/30-days-python/blob/main/Asabeneh_30_Days_of_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Asabeneh/30-Days-of-python(DAY 2)

# %%
from ast import keyword

#Variables level 1
firstname = 'Humaira'
lastname = 'Jamadar'
fullname = 'Humaira Salim Jamadar'
country = 'India'
city = 'Kurlap'
print (firstname , lastname , fullname, country , city)

#variables level 2
print(len(firstname) , " is the length of first name")
print(len(lastname),len(fullname),len(country),len(city),
      " these are respective lengths of lastname, full name, country and city.")
num1 = 5
num2 = 4
total = float(num1+num2)
dif= float(num1-num2)
prod= float(num1*num2)
div=float(num1/num2)
rem= float(num1%num2)
exp=float(num2^num1)
floor_div= float(num1//num2)
print("Numbers 5 and 4...",
      "\naddition = ",total,
      "\ndiffference = ",dif,
      "\nproduct = ", prod,
      "\ndivision = ", div,
      "\nremainder = ", rem,
      "\nexponent funtion'4 to the power of 5' = ", exp,
      "\nfloor division = ", floor_div)
area_of_circle = 30*30*3.14
print("Area of circle (radius =30) = ",float(area_of_circle),"sq.m")
circum_of_circle = 2*30*3.14
print("circumference of same = ",float(circum_of_circle),"m")

# %%
rad=input("Enter your desired radius = ")
new_area= float(rad)**2*3.14
print("Area of your circle = ",float(new_area))
new_circum=float(rad)*2*3.14
print("Area of your circle = ",float(new_circum))

# %% [markdown]
# #Asabeneh/30-Days-of-python(DAY 3)

# %%
age=int(input("enter your age = ")) #1
height=float(input("enter your height = ")) #2
comp_num=input("Enter a complex number = ") #3

# %%
#4 area of triangle
b=float(input("Enter the length of the base of triangle "))
h=float(input("Enter the lenght of the height of triangle "))
areatri=b*h*0.5
print("Area of triangle is " , areatri)

# %%
#5 perimeter of triangle
a= float(input("Enter the length of first side of the triangle = "))
b= float(input("Enter the length of second side of the triangle = "))
c= float(input("Enter the length of third side of the triangle = "))
perim=a+b+c
print("The perimeter of the triangle is ",perim)

# %%
#6rectangle area and perimeter
leng=float(input("Enter length of rectangle = "))
bred=float(input("Enter bredth of rectangle = "))
area_rec=leng*bred
perim_rect=leng*2+bred*2
print("Area of the rectangle is ", area_rec,
      "\nPerimeter of the rectangle is ",perim_rect)

# %%
#7circle area and perimeter
r=float(input("Enter radius = "))
area_circle=r**2*3.14
perim_circle=2*3.14
print("Area of circle is ",area_circle,
      "\nPerimeter of circle is ",perim_circle)

# %%
#8 straight line eqn
m1=2
c=-2
print("Slope is ",m1,
      "\nY intercept is ",c)
#9 st line
x1=2.0
x2=6.0
y1=2.0
y2=10.0
m2=y2-y1/x2-x1
euclid = ((x2-x1)**2 + (y2-y1)**2)**0.5
print("Euclidean distance is ",euclid)
print("Slope is ",m2)
#10 comparison of slopes
comp1= m1>m2
comp2=m1<m2
print("Slope 1 > Slope 2: ", comp1,
      "\nSlope 1 < Slope2: ", comp2)

# %%
#11 quadratic equation
a=1.0
b=6.0
c=9.0
D=b**2-4*a*c
x_1=(-b+D**0.5)/2*a
x_2=(-b-D**0.5)/2*a
print("Value of x is",x_1," or",x_2)

# %%
import builtins
#12 string funs
print(builtins.len("python"))
print(builtins.len("dragon"))
print(builtins.len("python") != builtins.len("dragon"))
#13 use of in and and
print("on"in "python" and "on" in "dragon")
#14 use of in
print("jargon" in "I hope this course is not full of jargon")
#15 use of not in
print("on" not in "python" and "on" not in "dragon" )
#16 length data type conversion
print(float(builtins.len("python")))
print(str(builtins.len("python")))
