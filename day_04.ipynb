# %% [markdown]
# <a href="https://colab.research.google.com/github/Humaira-jam/30-days-python/blob/main/day_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import builtins
#1
str1= "Thrity" + "Days" + "Of" + "Python"
#2,3
company="Coding" + "For" +"All"
#4
print(company)
#5
print(builtins.len(company))
