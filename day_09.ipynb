# %% [markdown]
# <a href="https://colab.research.google.com/github/Humaira-jam/30-days-python/blob/main/day_09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Level 1(DAY_09)

# %%
age=input("Enter your age: ")
if int(age)>=18:
  print('Your are old enough to drive!')
else:
  more_years=18-age
  print(f'You need {more_years} more years to learn to drive!')
# Out:
# Enter your age: 18
# Your are old enough to drive!

# %%
your_age=input('Enter your age: ')
my_age= 18
if int(your_age) > int(my_age):
  diff=int(your_age)-int(my_age)
  print(f'You are {diff} years older tham me!')
elif int(your_age) < int(my_age):
  diff=int(my_age)-int(your_age)
  print(f'You are {diff} years younger than me!')
else:
  print(f'You and me are same aged!')
# Out:
# Enter your age: 21
# You are 3 years older tham me!
