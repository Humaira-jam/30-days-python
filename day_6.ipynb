# %% [markdown]
# <a href="https://colab.research.google.com/github/Humaira-jam/30-days-python/blob/main/day_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#level_1
empty_tuple=tuple()
brothers=('fardin',)
sisters=('qahu', 'siddu', 'suahana')
siblings = brothers + sisters
print("No. of siblings : ",len(siblings))
siblings=list(siblings)
siblings.append('Rayyan')
siblings.append('Salim')
family_members=tuple(siblings)
print(family_members)
# Out:
# No. of siblings :  4
# ('fardin', 'qahu', 'siddu', 'suahana', 'Rayyan', 'Salim')

# %%
#level_2
