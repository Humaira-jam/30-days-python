# %% [markdown]
# <a href="https://colab.research.google.com/github/Humaira-jam/30-days-python/blob/main/day_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Only one level : DICTIONARIES

# %%
dog={'Name':'Tuffy',
     'Color':'White',
     'Breed':'Indian Spitz',
     'legs':4}
student={'first_name':'Humaira',
         'last_name':'Jamadar',
         'gender':'Female',
         'age':18,
         'marital status':'Unmarried',
         'skills':['Python Basics', 'swimming', 'sketching'],
         'country':'India',
         'address':{'city':'Islampur',
                    'district':'Sanglali',
                    'taluka':'Walwa',
                    'landmark':'Near Gram Panchayat, Kurlap'
                    }
         }
print("elements in student dictionary: ", len(student))
print("Student's Skill set: ",student.get('skills'),'\n',type(student['skills']))
extra_skills=input("Enter any more skills: ").split(',')
student['skills'].extend(extra_skills)
print(student["skills"])
attributes=student.keys()
print(attributes)
info=student.values()
print(info)
print(student.items())
del dog['legs']
del dog
# Out:
# elements in student dictionary:  8
# Student's Skill set:  ['Python Basics', 'swimming', 'sketching']
#  <class 'list'>
# Enter any more skills: painting, acting
# ['Python Basics', 'swimming', 'sketching', 'painting', ' acting']
# dict_keys(['first_name', 'last_name', 'gender', 'age', 'marital status', 'skills', 'country', 'address'])
# dict_values(['Humaira', 'Jamadar', 'Female', 18, 'Unmarried', ['Python Basics', 'swimming', 'sketching', 'painting', ' acting'], 'India', {'city': 'Islampur', 'district': 'Sanglali', 'taluka': 'Walwa', 'landmark': 'Near Gram Panchayat, Kurlap'}])
# dict_items([('first_name', 'Humaira'), ('last_name', 'Jamadar'), ('gender', 'Female'), ('age', 18), ('marital status', 'Unmarried'), ('skills', ['Python Basics', 'swimming', 'sketching', 'painting', ' acting']), ('country', 'India'), ('address', {'city': 'Islampur', 'district': 'Sanglali', 'taluka': 'Walwa', 'landmark': 'Near Gram Panchayat, Kurlap'})])
